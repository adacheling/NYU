# %%
from googlemaps import *

# %%
from googlemaps import Client as GoogleMaps

# %%
GoogleMaps.geocode(query, sensor='false', oe='utf8', ll='', spn='', gl='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-306aaf05d285> in <module>()
# ----> 1 GoogleMaps.geocode(query, sensor='false', oe='utf8', ll='', spn='', gl='')
#
# NameError: name 'query' is not defined

# %%
gmaps = GoogleMaps("AIzaSyCvNvDXdhzAuDQX3eX-DjVk5nREVESL7R0")
address = '350 Fifth Avenue New York, NY'
result = gmaps.geocode(address)
# Out:
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# <ipython-input-40-f8b5c072c1f8> in <module>()
#       1 gmaps = GoogleMaps("AIzaSyCvNvDXdhzAuDQX3eX-DjVk5nREVESL7R0")
#       2 address = '350 Fifth Avenue New York, NY'
# ----> 3 result = gmaps.geocode(address)
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in wrapper(*args, **kwargs)
#     363     def wrapper(*args, **kwargs):
#     364         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 365         result = func(*args, **kwargs)
#     366         try:
#     367             del args[0]._extra_params
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params).get("results", [])
#      69
#      70
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# ~/anaconda3/lib/python3.7/site-packages/googlemaps-3.0.2-py3.7.egg/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     208         elapsed = datetime.now() - first_request_time
#     209         if elapsed > self.retry_timeout:
# --> 210             raise googlemaps.exceptions.Timeout()
#     211
#     212         if retry_counter > 0:
#
# Timeout:

# %%
print(result)
# Out:
# [{'address_components': [{'long_name': '350', 'short_name': '350', 'types': ['street_number']}, {'long_name': '5th Avenue', 'short_name': '5th Ave', 'types': ['route']}, {'long_name': 'Manhattan', 'short_name': 'Manhattan', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'New York', 'short_name': 'New York', 'types': ['locality', 'political']}, {'long_name': 'New York County', 'short_name': 'New York County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10118', 'short_name': '10118', 'types': ['postal_code']}], 'formatted_address': '350 5th Ave, New York, NY 10118, USA', 'geometry': {'location': {'lat': 40.7484799, 'lng': -73.9854245}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.7498288802915, 'lng': -73.98407551970848}, 'southwest': {'lat': 40.7471309197085, 'lng': -73.98677348029149}}}, 'place_id': 'ChIJn6wOs6lZwokRLKy1iqRcoKw', 'plus_code': {'compound_code': 'P2X7+9R New York, United States', 'global_code': '87G8P2X7+9R'}, 'types': ['street_address']}]

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()
location = geolocator.geocode("175 5th Avenue NYC")
print(location.address)
print((location.latitude, location.longitude))
# Out:
# /Users/cheling/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# Flatiron Building, 175, 5th Avenue, Flatiron District, Manhattan, Manhattan Community Board 5, New York County, NYC, New York, 10010, USA
# (40.7410861, -73.9896298241625)
